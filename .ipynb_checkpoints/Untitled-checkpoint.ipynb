# %%
ls
# Out:
# checkpoints/                               README.md
# CIKM_Eva/                                  requirements.txt
# cikm_predrnn_pp_run_cikm_dataloader.py     SAC_LSTM_shengteng.py
# cikm_predrnn_pp_run_cikm_dataloader_SA.py  script/
# core/                                      supported_api.csv
# custom_supported_api.csv                   test/
# data_provider/                             unsupported_api.csv
# davinci/                                   Untitled.ipynb
# deleted_api.csv                            x2mindspore.log
# rank_0/                                    x2ms_adapter/

# %%
./SAC_LSTM_shengteng.py
# Out:
#   File "/tmp/ipykernel_17336/4270064411.py", line 1
#     ./SAC_LSTM_shengteng.py
#     ^
# SyntaxError: invalid syntax

# %%
# %run SAC_LSTM_shengteng.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/envs/MindSpore/lib/python3.7/site-packages/skimage/__init__.py in <module>
#     150     try:
# --> 151         from ._shared import geometry
#     152         del geometry
#
# ImportError: /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/skimage/_shared/../../scikit_image.libs/libgomp-d22c30c5.so.1.0.0: cannot allocate memory in static TLS block
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~/work/IDA_LSTM-master-huawei_x2ms/SAC_LSTM_shengteng.py in <module>
#      21 from core.utils import preprocess
#      22 import core.trainer as trainer
# ---> 23 from data_provider.CIKM.data_iterator import *
#      24 import math
#      25 import moxing as mox
#
# ...

# %%
pip list
# Out:
# Package                Version
# ---------------------- ------------------
# addict                 2.4.0
# APScheduler            3.8.1
# arrow                  1.2.2
# asgiref                3.4.1
# asttokens              2.0.5
# astunparse             1.6.3
# attrs                  19.3.0
# auto-tune              0.1.0
# backcall               0.2.0
# backports.zoneinfo     0.2.1
# binaryornot            0.4.4
# boto3                  1.12.22
# botocore               1.15.49
# certifi                2021.10.8
# cffi                   1.14.0
# chardet                3.0.4
# charset-normalizer     2.0.12
# click                  8.1.3
# cloudpickle            2.0.0
# colorama               0.4.4
# configparser           5.2.0
# cookiecutter           2.1.1
# cryptography           3.4.7
# cycler                 0.11.0
# Cython                 0.29.14
# debugpy                1.6.2
# decorator              4.4.1
# Django                 3.2.9
# docutils               0.15.2
# ...

# %%
pip install imageio
# Out:
# Looking in indexes: http://pip.modelarts.private.com:8888/repository/pypi/simple
# ...
#      |████████████████████████████████| 3.4 MB 43.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 53.1 MB/s eta 0:00:01
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# modelarts 1.4.7 requires Pillow<=9.0.1, but you have pillow 9.3.0 which is incompatible.
# modelarts 1.4.7 requires requests~=2.27.1, but you have requests 2.23.0 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-image
# Out:
# Looking in indexes: http://pip.modelarts.private.com:8888/repository/pypi/simple
# ...
#      |████████████████████████████████| 13.4 MB 49.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 178 kB 58.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.9 MB 49.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.6 MB 44.4 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for PyWavelets: filename=PyWavelets-1.4.0-cp37-cp37m-linux_aarch64.whl size=5857143 sha256=a2de60312ef038c810066ed4d724ea3647fa94603ac673bd2598a07d8585492e
#   Stored in directory: /home/ma-user/.cache/pip/wheels/b4/3d/dd/4afe5e1c056b3d849baf97914651e2eb9c0f896cd11b786a55
# Successfully built PyWavelets
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall scikit-image
# Out:
# Found existing installation: scikit-image 0.19.3
# Uninstalling scikit-image-0.19.3:
#   Would remove:
#     /home/ma-user/anaconda3/envs/MindSpore/bin/skivi
#     /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/doc/ext/*
#     /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/scikit_image-0.19.3.dist-info/*
#     /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/scikit_image.libs/libgomp-d22c30c5.so.1.0.0
#     /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/skimage/*
# Proceed (Y/n)?

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17336/3563912222.py in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
y
