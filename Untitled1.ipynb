# %%
# %run SAC_LSTM_shengteng.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/skimage/__init__.py in <module>
#     120     try:
# --> 121         from ._shared import geometry
#     122         del geometry
#
# ImportError: /home/ma-user/.local/lib/python3.7/site-packages/skimage/_shared/../../scikit_image.libs/libgomp-d22c30c5.so.1.0.0: cannot allocate memory in static TLS block
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~/work/IDA_LSTM-master-huawei_x2ms/SAC_LSTM_shengteng.py in <module>
#      21 from core.utils import preprocess
#      22 import core.trainer as trainer
# ---> 23 from data_provider.CIKM.data_iterator import *
#      24 import math
#      25 import moxing as mox
#
# ...

# %%
pip list
# Out:
# Package                Version
# ---------------------- ------------------
# addict                 2.4.0
# APScheduler            3.8.1
# arrow                  1.2.2
# asgiref                3.4.1
# asttokens              2.0.5
# astunparse             1.6.3
# attrs                  19.3.0
# auto-tune              0.1.0
# backcall               0.2.0
# backports.zoneinfo     0.2.1
# binaryornot            0.4.4
# boto3                  1.12.22
# botocore               1.15.49
# certifi                2021.10.8
# cffi                   1.14.0
# chardet                3.0.4
# charset-normalizer     2.0.12
# click                  8.1.3
# cloudpickle            2.0.0
# colorama               0.4.4
# configparser           5.2.0
# cookiecutter           2.1.1
# cryptography           3.4.7
# cycler                 0.11.0
# Cython                 0.29.14
# debugpy                1.6.2
# decorator              4.4.1
# Django                 3.2.9
# docutils               0.15.2
# ...

# %%
# %run SAC_LSTM_shengteng.py
# Out:
# INFO:root:Listing OBS: 1000
# INFO:root:Listing OBS: 2000
# INFO:root:Listing OBS: 3000
# INFO:root:Listing OBS: 4000
# INFO:root:Listing OBS: 5000
# INFO:root:Listing OBS: 6000
# INFO:root:Listing OBS: 7000
# INFO:root:Listing OBS: 8000
# INFO:root:Listing OBS: 9000
# INFO:root:Listing OBS: 10000
# INFO:root:Listing OBS: 11000
# INFO:root:Listing OBS: 12000
# INFO:root:Listing OBS: 13000
# INFO:root:Listing OBS: 14000
# INFO:root:Listing OBS: 15000
# INFO:root:Listing OBS: 16000
# INFO:root:Listing OBS: 17000
# INFO:root:Listing OBS: 18000
# INFO:root:Listing OBS: 19000
# INFO:root:Listing OBS: 20000
# INFO:root:Listing OBS: 21000
# INFO:root:Listing OBS: 22000
# INFO:root:Listing OBS: 23000
# INFO:root:Listing OBS: 24000
# INFO:root:Listing OBS: 25000
# INFO:root:Listing OBS: 26000
# INFO:root:Listing OBS: 27000
# INFO:root:Listing OBS: 28000
# INFO:root:Listing OBS: 29000
# INFO:root:Listing OBS: 30000
# INFO:root:Listing OBS: 31000
# INFO:root:Listing OBS: 32000
# ...

# %%
npu-smi info watch

# %%
npu-smi info

# %%
npu-smi info watch
